# %% [markdown]
# The lines those start with "#" are comments.
# / - forward slash
# \ - back slash
# jupyter notebooks

# %%
'''
Prints a line to the console
print('Hello, \'BAMU\', Python Prgramming 123')

x = 23
print(type(x))
y = 10.10
print(type(y))
p = complex(2,3)
print(p)
z = complex('3+4j')
print(type(z))

Function call - ()
indexing - []
Function Definition - {}



physics = 80
chemistry = 90
maths = 95
#s1[0] = "R"print(s1[0])
#print(f'I love my {s1}')
print(f'The student got following marks :-')
print(f' Physics   - {physics} ')
print(f' Chemistry - {chemistry} ')
print(f' Maths     - {maths} ')

s2 = 'University'
print(s1 + ' '+ s2)
print(s1 * 2)
# print(len(s2))

#print(s2[0])
s1 = "Bamu University Dharashiv"
print(s1[::-1])

l = [1, 2, 3.14, "India"]
l.insert(1,-20)

print(f'This is list l - {l}')
print()

marks = 80

if(marks >= 75 ):
  print("very good !")
else:
  print("Need to improve!")

# Operand , Operator Unary Operator 
print(2+4)
print(2-4)
print(2*4)
print(4/2)
print(3**2)
print(22 % 7)

print(2+4-3**2/5)  # 2+4-9/5 => 2+4-1.8 => 4.2

print(9//2)

name = input("Please enter your name")
print(name)
#print(*range(10))

for i in range(10):
  print("Hello", "World")

print(len(t1))            # Length: 3
print(max(t1))            # Maximum: 3
print(min(t1))            # Minimum: 1
print(sum(t1))
'''

t1 = (1,2,3,4)
a, b, c, d = t1 
print(a, b, c, d)
# Out:
# 1 2 3 4
